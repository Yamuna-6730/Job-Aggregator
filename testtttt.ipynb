# %%
from main import app
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from main import app
#
# ImportError: cannot import name 'app' from 'main' (s:\PBL-CLIENT-4\main.py)

# %%
from main import run_once

# %%
run_once
